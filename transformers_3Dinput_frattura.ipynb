# %%
# %config IPCompleter.greedy=True #si puo' cancellare, è per avere l'autocompletion su jupyter notebook ma non pare funzionare

import os
import re
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image, ImageOps
import numpy as np
import pandas as pd
import csv
from utils_frattura import *
import random
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

class PointsDataset(Dataset):
    def __init__(self, root_dir, transform=None, padding=None, noise=None):
        """
        Args:
            root_dir (str): Root directory containing subfolders, each representing a sample.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.root_dir = root_dir
        self.transform = transform
        self.data = []
        self.sim_info = []
        self.noise = noise
        self.noise_std = 1.0
        try:
            with open(os.path.join(self.root_dir, "Simulations_Info.csv"), newline='') as file:
                reader = csv.DictReader(file)
                for row in reader:
                    index = int(row["INDEX"])
                    completed = row["COMPLETED"].strip().lower() in ["true", "1", "yes"]
                    self.sim_info.append((index, completed))
        except:
            self.sim_info = [(i, True) for i in range(5001)]

        # Iterate over each subfolder in root_dir and load all data
        for subfolder in os.listdir(root_dir):
            subfolder_path = os.path.join(root_dir, subfolder)
            sample_idx = [int(s) for s in re.findall(r'\d+', subfolder)]  # Extract the first number in the subfolder name
            if sample_idx:
                sample_idx = sample_idx[0]
            else:
                continue
           
            completed = next((item[1] for item in self.sim_info if item[0] == sample_idx), None) #completed refers to abaqus simulation stsatus
            if os.path.isdir(subfolder_path) and sample_idx and completed:
                init_coords_circle_file = next((f for f in os.listdir(subfolder_path) if f.endswith('input_coordinates_circle_1.csv')), None)
                before_coords_file = next((f for f in os.listdir(subfolder_path) if f.endswith('input_coordinates_circle_2.csv')), None)
                gt_file = next((f for f in os.listdir(subfolder_path) if f.endswith('output_displacement_external.csv')), None)
                init_coord_plate_file = os.path.join(root_dir,'plate_initial_coordinates.csv')
                # Load ground truth data (displacement external)
                init_coord_plate_data = pd.read_csv(os.path.join(subfolder_path, init_coord_plate_file), skiprows=0, usecols=[1, 2, 3])
                init_coord_plate_data = init_coord_plate_data.to_numpy().flatten()
                init_coord_plate_data = torch.tensor(init_coord_plate_data).float()
                
                if init_coords_circle_file and before_coords_file and gt_file and init_coord_plate_file:

                    #load initial circle data
                    init_coords_circle_data = pd.read_csv(os.path.join(subfolder_path, init_coords_circle_file), skiprows=0, usecols=[1, 2, 3])
                    init_coords_circle_data = init_coords_circle_data.to_numpy()
                    init_coords_circle_data = torch.tensor(init_coords_circle_data).float()

                    #load before_impact circle data
                    before_coords_data = pd.read_csv(os.path.join(subfolder_path, before_coords_file), skiprows=0, usecols=[1, 2, 3])
                    before_coords_data = before_coords_data.to_numpy()
                    before_coords_data = torch.tensor(before_coords_data).float()
                    
                    total_data = torch.cat((init_coords_circle_data,before_coords_data),1)
                    if (padding is not None) and total_data.shape[0]<padding:
                        total_data = zero_pad_tensor(total_data,target_size=padding)
                    #import pdb;pdb.set_trace()
                    gt_data = pd.read_csv(os.path.join(subfolder_path, gt_file), skiprows=0, usecols=[1, 2, 3])
                    gt_data = gt_data.to_numpy().flatten()
                    gt_data = torch.tensor(gt_data).float()

                    class_data = pd.read_csv(os.path.join(subfolder_path, gt_file), skiprows=0, usecols=[4])
                    class_data = class_data.to_numpy().flatten()
                    class_data = torch.tensor(class_data).float()                    

                    # Append the final_image, gt_data, init_coord_plate_data tuple to the data list
                    self.data.append((total_data, gt_data, class_data, init_coord_plate_data))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Retrieve preloaded data
        total_data, gt_data, labels_data, init_coord_plate_data = self.data[idx]

        # Apply transformation if available
        if self.transform:
            total_data = self.transform(total_data)
        if self.noise:
            noise = torch.randn_like(signal) * self.noise_std
            total_data+=noise
        return total_data, gt_data, labels_data, init_coord_plate_data

# %%
from torch.utils.data import random_split
from torch import nn
import torch.optim as optim
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
import numpy as np
from tqdm import tqdm
from torchvision.models import  ResNet18_Weights
import copy
from transformers import ConvNextConfig, ConvNextModel
import math 
from torch.utils.tensorboard import SummaryWriter
from torch.optim.lr_scheduler import OneCycleLR
from utils_frattura import *

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # Shape: (1, max_len, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        # x shape: (batch_size, seq_len, d_model)
        x = x + self.pe[:, :x.size(1), :]  # Add positional encoding
        return x

class Transformer3DPointsModel(nn.Module):
    def __init__(self, input_dim,input_seq_len, d_model, nhead, num_encoder_layers, dim_feedforward, output_dim, dropout=0.1):
        super(Transformer3DPointsModel, self).__init__()
        self.d_model = d_model
        self.linear_in = nn.Linear(input_dim, d_model)  # Project input to d_model
        self.positional_encoding = PositionalEncoding(d_model)
        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout, batch_first=True),
            num_encoder_layers
        )
        self.attention = AttentionLayer(d_model)  # Add attention layer
        #self.linear_out = nn.Linear(d_model, output_dim)  # Map to the desired output size
        self.linear_out = nn.Linear(d_model*input_seq_len, output_dim)  # Map to the desired output size
        self.linear_class = nn.Linear(d_model*input_seq_len, output_dim//3)

    def forward(self, src, src_mask=None):
        
        # src shape: (batch_size, seq_len, input_dim)
        src = self.linear_in(src)  # Project input to d_model
        src = self.positional_encoding(src)  # Add positional encoding
        #memory = self.transformer_encoder(src, src_key_padding_mask=src_mask)  # Pass through transformer encoder
                # memory shape: (batch_size, seq_len, d_model)
        # Zero out padded tokens using src_mask
        if src_mask is not None:
            memory = memory * src_mask.unsqueeze(-1)
            src_key_padding_mask = (src_mask == 0) # Convert 0/1 mask to boolean
            memory = self.transformer_encoder(src, src_key_padding_mask=src_key_padding_mask)
        else:
            memory = self.transformer_encoder(src)
            
        # Apply attention mechanism
        #aggregated = self.attention(memory, src_mask)  # Shape: (batch_size, d_model)

        # Map to the desired output size
        #output = self.linear_out(aggregated)  # Shape: (batch_size, output_dim)

        memory = memory.view(memory.shape[0], -1)  # Shape: (batch_size, d_model, seq_len)
        # Map to the desired output size
        output = self.linear_out(memory)  # Shape: (batch_size, output_dim)
        output_class = self.linear_class(memory)  # Shape: (batch_size, output_dim)        
        return output, output_class

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(in_features=288, out_features=2493, bias=True)
        self.fc2 = nn.Linear(in_features=2493, out_features=1386, bias=True)
        self.fc3 = nn.Linear(in_features=1386, out_features=280, bias=True)
        self.relu = nn.ReLU()
    def forward(self, src, src_mask=None):
        src = src.view(src.shape[0],-1)
        x = self.fc1(self.relu(src))
        x = self.fc2(self.relu(x))
        x = self.fc3(self.relu(x))
        return x

        
# Training Setup with Best Model Saving
def train_model(batch_size, n_points, model, epochs=3, learning_rate=0.0001, optimizer= None, scheduler = None, train_loader=None, test_loader=None, norm_values=None, input_norm_values=None):
    #smoothness_loss_fn = SmoothnessLoss(weight=0.0)  # starting weight
    criterion = nn.MSELoss()
    criterion_class = nn.BCEWithLogitsLoss()
    # Initialize variables for tracking best model
    best_model_weights = None
    best_test_loss = float('inf')
    best_epoch=0
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        #smoothness_loss_fn.weight = time_varying_weight(epoch, 10, 20, max_weight=0.1)
        for images, targets, labels, init_data in train_loader:
            images = normalize_targets(images,input_norm_values).to(device)
            #import pdb; pdb.set_trace()
            #attention_mask = create_attention_mask(images).to(device)
            labels=labels.to(device)
            
            targets = normalize_targets(targets,norm_values).to(device)              
            optimizer.zero_grad()
            outputs,outputs_class = model(images,None)
            loss = criterion(outputs, targets)

            loss2 = criterion_class(outputs_class,labels)
            loss = loss + loss2
            loss.backward()
            optimizer.step()
            if scheduler is not None: scheduler.step()  # Update learning rate
            
            with torch.no_grad():
                denorm_outputs = denormalize_targets(outputs, norm_values)
                denorm_targets = denormalize_targets(targets,norm_values)
                denorm_loss = criterion(denorm_outputs, denorm_targets)
                running_loss += denorm_loss.item() * images.size(0)
        
        train_loss = running_loss/len(train_loader.dataset)
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.5f}",end='')
        writer.add_scalar('Loss/train', train_loss*1000, epoch+1)
        # Evaluate on test set
        model.eval()
        correct = 0
        total=0
        test_loss = 0.0
        with torch.no_grad():
            for images, targets, labels, init_data in test_loader:
                #import pdb; pdb.set_trace()
                images = normalize_targets(images,input_norm_values).to(device)
                targets = normalize_targets(targets, norm_values).to(device)
                labels = labels.to(device)
                #attention_mask = create_attention_mask(images).to(device)
                outputs, outputs_class = model(images,None)
                loss = criterion(denormalize_targets(outputs,norm_values), denormalize_targets(targets,norm_values))
                test_loss += loss.item()*images.size(0)
                # === Compute binary classification accuracy ===
                probs = torch.sigmoid(outputs_class)       # shape: (batch_size, N)
                preds = (probs > 0.5).float()              # binary predictions: 0 or 1
                correct += (preds == labels).sum().item()  # count correct predictions
                total += labels.numel()                    # total number of labels
        mean_accuracy = correct / total 
        mean_test_loss = test_loss/len(test_loader.dataset)
        print(f"Mean Accuracy: {mean_accuracy:.4f}, Test Loss: {mean_test_loss:.5f}")
        writer.add_scalar('Loss/test', mean_test_loss*1000, epoch+1)
        # Save the model weights if this epoch has the lowest test loss so far
        if mean_test_loss < best_test_loss:
            torch.save(model, "./full_model.pth")
            torch.save(model.state_dict(), "model_state_dict.pth")
            best_test_loss = mean_test_loss
            best_model_weights = copy.deepcopy(model.state_dict())
            print(f"New best model saved with test loss: {best_test_loss:.5f}")
            best_epoch = epoch
            writer.add_scalar('Loss/best_test', best_test_loss*1000, best_epoch+1)
        writer.flush()
    # Load the best model weights at the end of training
    if best_model_weights:
        model.load_state_dict(best_model_weights)
        print(f"Loaded best model weights with test loss: {best_test_loss:.5f}, epoch: {best_epoch+1:3d}")
    else:
        print("Warning: No best model weights found.")
    
    print("Training Complete")
    return model

writer = SummaryWriter('runs/experiment_name',flush_secs=5)
device = "cuda" if torch.cuda.is_available() else "cpu"
input_seq_len = 98
input_dim = 6  # Each input is a sequence of 3Dx2 points (x, y, z)
d_model = 512  # Embedding dimension
nhead = 4  # Number of attention heads
num_encoder_layers = 4  # Number of transformer encoder layers
dim_feedforward = 512  # Feedforward network dimension
n_points = 2738   
output_dim = n_points*3  # Each output is a 3D point (x, y, z)
dropout = 0.0

model = Transformer3DPointsModel(input_dim, input_seq_len, d_model, nhead, num_encoder_layers, dim_feedforward, output_dim, dropout).to(device)
#model = MLP().to(device)
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")

#dataset = ImagePairDataset("/mnt/hdd1/deformazione-2d-parametrica/", transform=transform)
dataset = PointsDataset("/home/fabiana/libraries/my_work/simulazioni_3d_frattura/", transform=None,padding=input_seq_len)
test_split = 0.2 
batch_size = 128
# Split dataset into train and test sets
test_size = int(test_split * len(dataset))
train_size = len(dataset) - test_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])
train_dataset.noise = True
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

norm_values=calculate_target_normalization(train_loader)
input_norm_values=calculate_input_normalization(train_loader)
#import pdb; pdb.set_trace()
learning_rate = 0.0001
n_epochs = 700
warmup_steps = 100  # Number of warm-up steps
total_steps = n_epochs * len(train_loader)  # Total training steps
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = OneCycleLR(optimizer, max_lr=learning_rate, total_steps=total_steps, pct_start=warmup_steps/total_steps)

trained_model = train_model(batch_size,n_points, model=model, epochs=n_epochs,learning_rate=learning_rate, optimizer=optimizer, scheduler=scheduler,  train_loader=train_loader,test_loader=test_loader,norm_values=norm_values, input_norm_values=input_norm_values)
writer.close()
# Out:
# Number of parameters: 555854537
# Epoch [1/700], Train Loss: 6.15528Mean Accuracy: 0.9790, Test Loss: 2.69212
# New best model saved with test loss: 2.69212
# Epoch [2/700], Train Loss: 5.67574Mean Accuracy: 0.9820, Test Loss: 2.80473
# Epoch [3/700], Train Loss: 5.80709Mean Accuracy: 0.9830, Test Loss: 3.16562
# Epoch [4/700], Train Loss: 5.61174Mean Accuracy: 0.9830, Test Loss: 2.67572
# New best model saved with test loss: 2.67572
# Epoch [5/700], Train Loss: 5.51517Mean Accuracy: 0.9834, Test Loss: 2.32910
# New best model saved with test loss: 2.32910
# Epoch [6/700], Train Loss: 5.33570Mean Accuracy: 0.9825, Test Loss: 2.42733
# Epoch [7/700], Train Loss: 5.26201Mean Accuracy: 0.9833, Test Loss: 2.49933
# Epoch [8/700], Train Loss: 5.33085Mean Accuracy: 0.9836, Test Loss: 2.39277
# Epoch [9/700], Train Loss: 5.24729Mean Accuracy: 0.9839, Test Loss: 2.42481
# Epoch [10/700], Train Loss: 5.24822Mean Accuracy: 0.9833, Test Loss: 2.22490
# New best model saved with test loss: 2.22490
# Epoch [11/700], Train Loss: 5.19059Mean Accuracy: 0.9842, Test Loss: 2.16527
# New best model saved with test loss: 2.16527
# Epoch [12/700], Train Loss: 5.09851Mean Accuracy: 0.9837, Test Loss: 2.21719
# Epoch [13/700], Train Loss: 5.14754Mean Accuracy: 0.9833, Test Loss: 2.27469
# Epoch [14/700], Train Loss: 5.12045Mean Accuracy: 0.9834, Test Loss: 2.11454
# New best model saved with test loss: 2.11454
# Epoch [15/700], Train Loss: 5.08241Mean Accuracy: 0.9833, Test Loss: 2.02750
# New best model saved with test loss: 2.02750
# Epoch [16/700], Train Loss: 4.92112Mean Accuracy: 0.9851, Test Loss: 2.05297
# Epoch [17/700], Train Loss: 4.80475Mean Accuracy: 0.9849, Test Loss: 1.92602
# New best model saved with test loss: 1.92602
# Epoch [18/700], Train Loss: 4.84159Mean Accuracy: 0.9854, Test Loss: 2.23595
# Epoch [19/700], Train Loss: 4.89254Mean Accuracy: 0.9862, Test Loss: 1.78289
# New best model saved with test loss: 1.78289
# Epoch [20/700], Train Loss: 4.72453Mean Accuracy: 0.9859, Test Loss: 1.78944
# Epoch [21/700], Train Loss: 4.72348Mean Accuracy: 0.9848, Test Loss: 2.25351
# Epoch [22/700], Train Loss: 4.82591Mean Accuracy: 0.9864, Test Loss: 1.86833
# Epoch [23/700], Train Loss: 4.69720Mean Accuracy: 0.9854, Test Loss: 1.96454
# Epoch [24/700], Train Loss: 4.67089Mean Accuracy: 0.9870, Test Loss: 1.69859
# New best model saved with test loss: 1.69859
# Epoch [25/700], Train Loss: 4.60254Mean Accuracy: 0.9825, Test Loss: 2.89597
# Epoch [26/700], Train Loss: 4.96300Mean Accuracy: 0.9869, Test Loss: 1.76317
# Epoch [27/700], Train Loss: 4.62057Mean Accuracy: 0.9878, Test Loss: 1.77424
# Epoch [28/700], Train Loss: 4.57950Mean Accuracy: 0.9880, Test Loss: 1.65370
# New best model saved with test loss: 1.65370
# Epoch [29/700], Train Loss: 4.49113Mean Accuracy: 0.9876, Test Loss: 1.77133
# Epoch [30/700], Train Loss: 4.65976Mean Accuracy: 0.9886, Test Loss: 1.62334
# New best model saved with test loss: 1.62334
# Epoch [31/700], Train Loss: 4.46260Mean Accuracy: 0.9883, Test Loss: 1.71285
# Epoch [32/700], Train Loss: 4.62132Mean Accuracy: 0.9891, Test Loss: 1.60434
# New best model saved with test loss: 1.60434
# Epoch [33/700], Train Loss: 4.57713Mean Accuracy: 0.9886, Test Loss: 1.62165
# Epoch [34/700], Train Loss: 4.56119Mean Accuracy: 0.9881, Test Loss: 1.64752
# Epoch [35/700], Train Loss: 4.50086Mean Accuracy: 0.9885, Test Loss: 1.67666
# Epoch [36/700], Train Loss: 4.46903Mean Accuracy: 0.9888, Test Loss: 1.76855
# Epoch [37/700], Train Loss: 4.50068Mean Accuracy: 0.9890, Test Loss: 1.80766
# Epoch [38/700], Train Loss: 4.52141Mean Accuracy: 0.9897, Test Loss: 1.71323
# Epoch [39/700], Train Loss: 4.37111Mean Accuracy: 0.9883, Test Loss: 1.90033
# Epoch [40/700], Train Loss: 4.44673Mean Accuracy: 0.9887, Test Loss: 1.93291
# Epoch [41/700], Train Loss: 4.61442Mean Accuracy: 0.9895, Test Loss: 1.63401
# Epoch [42/700], Train Loss: 4.41128Mean Accuracy: 0.9902, Test Loss: 1.60362
# New best model saved with test loss: 1.60362
# Epoch [43/700], Train Loss: 4.53218Mean Accuracy: 0.9887, Test Loss: 1.75060
# Epoch [44/700], Train Loss: 4.40651Mean Accuracy: 0.9884, Test Loss: 1.73205
# Epoch [45/700], Train Loss: 4.47884Mean Accuracy: 0.9899, Test Loss: 1.60882
# Epoch [46/700], Train Loss: 4.40643Mean Accuracy: 0.9883, Test Loss: 2.06202
# Epoch [47/700], Train Loss: 4.72388Mean Accuracy: 0.9890, Test Loss: 1.66213
# Epoch [48/700], Train Loss: 4.35735Mean Accuracy: 0.9905, Test Loss: 1.59293
# New best model saved with test loss: 1.59293
# Epoch [49/700], Train Loss: 4.31795Mean Accuracy: 0.9900, Test Loss: 1.68240
# Epoch [50/700], Train Loss: 4.30976Mean Accuracy: 0.9904, Test Loss: 1.63187
# Epoch [51/700], Train Loss: 4.29701Mean Accuracy: 0.9909, Test Loss: 1.61798
# Epoch [52/700], Train Loss: 4.56028Mean Accuracy: 0.9899, Test Loss: 1.67524
# Epoch [53/700], Train Loss: 4.40481Mean Accuracy: 0.9879, Test Loss: 1.66682
# Epoch [54/700], Train Loss: 4.42851Mean Accuracy: 0.9907, Test Loss: 1.65635
# Epoch [55/700], Train Loss: 4.27684Mean Accuracy: 0.9895, Test Loss: 1.74510
# Epoch [56/700], Train Loss: 4.46192Mean Accuracy: 0.9903, Test Loss: 1.70318
# Epoch [57/700], Train Loss: 4.43222Mean Accuracy: 0.9899, Test Loss: 1.72355
# Epoch [58/700], Train Loss: 4.55623Mean Accuracy: 0.9904, Test Loss: 1.64339
# Epoch [59/700], Train Loss: 4.29778Mean Accuracy: 0.9909, Test Loss: 1.54972
# New best model saved with test loss: 1.54972
# Epoch [60/700], Train Loss: 4.32822Mean Accuracy: 0.9900, Test Loss: 1.63441
# Epoch [61/700], Train Loss: 4.32595Mean Accuracy: 0.9899, Test Loss: 1.69034
# Epoch [62/700], Train Loss: 4.27306Mean Accuracy: 0.9912, Test Loss: 1.61544
# Epoch [63/700], Train Loss: 4.09799Mean Accuracy: 0.9909, Test Loss: 1.71699
# Epoch [64/700], Train Loss: 4.22139Mean Accuracy: 0.9900, Test Loss: 1.91682
# Epoch [65/700], Train Loss: 4.55752Mean Accuracy: 0.9893, Test Loss: 1.67639
# Epoch [66/700], Train Loss: 4.30706Mean Accuracy: 0.9910, Test Loss: 1.63290
# Epoch [67/700], Train Loss: 4.12320Mean Accuracy: 0.9912, Test Loss: 2.20259
# Epoch [68/700], Train Loss: 4.28005Mean Accuracy: 0.9901, Test Loss: 2.18596
# Epoch [69/700], Train Loss: 4.17807Mean Accuracy: 0.9914, Test Loss: 1.86735
# Epoch [70/700], Train Loss: 4.11494Mean Accuracy: 0.9913, Test Loss: 1.69844
# Epoch [71/700], Train Loss: 4.03511Mean Accuracy: 0.9907, Test Loss: 2.04521
# Epoch [72/700], Train Loss: 4.38721Mean Accuracy: 0.9907, Test Loss: 1.80955
# Epoch [73/700], Train Loss: 4.16363Mean Accuracy: 0.9906, Test Loss: 1.79986
# Epoch [74/700], Train Loss: 4.17335Mean Accuracy: 0.9917, Test Loss: 1.79093
# Epoch [75/700], Train Loss: 3.94615Mean Accuracy: 0.9911, Test Loss: 2.04052
# Epoch [76/700], Train Loss: 4.24863Mean Accuracy: 0.9905, Test Loss: 2.02923
# Epoch [77/700], Train Loss: 4.26275Mean Accuracy: 0.9911, Test Loss: 1.80228
# Epoch [78/700], Train Loss: 4.03061Mean Accuracy: 0.9921, Test Loss: 1.81077
# Epoch [79/700], Train Loss: 4.05396Mean Accuracy: 0.9905, Test Loss: 2.31952
# Epoch [80/700], Train Loss: 4.36228Mean Accuracy: 0.9915, Test Loss: 2.31735
# Epoch [81/700], Train Loss: 3.96760Mean Accuracy: 0.9918, Test Loss: 1.96632
# Epoch [82/700], Train Loss: 4.02921Mean Accuracy: 0.9921, Test Loss: 1.98298
# Epoch [83/700], Train Loss: 4.21872Mean Accuracy: 0.9915, Test Loss: 1.83429
# Epoch [84/700], Train Loss: 4.06568Mean Accuracy: 0.9915, Test Loss: 1.94112
# Epoch [85/700], Train Loss: 3.81955Mean Accuracy: 0.9911, Test Loss: 2.00155
# Epoch [86/700], Train Loss: 4.20357Mean Accuracy: 0.9913, Test Loss: 2.18258
# Epoch [87/700], Train Loss: 4.07379Mean Accuracy: 0.9904, Test Loss: 2.06172
# Epoch [88/700], Train Loss: 4.00786Mean Accuracy: 0.9914, Test Loss: 2.01944
# Epoch [89/700], Train Loss: 3.96191Mean Accuracy: 0.9902, Test Loss: 1.90474
# Epoch [90/700], Train Loss: 4.03702Mean Accuracy: 0.9915, Test Loss: 2.02752
# Epoch [91/700], Train Loss: 4.10857Mean Accuracy: 0.9905, Test Loss: 2.11287
# Epoch [92/700], Train Loss: 4.14182Mean Accuracy: 0.9918, Test Loss: 1.91226
# Epoch [93/700], Train Loss: 3.73221Mean Accuracy: 0.9903, Test Loss: 1.94476
# Epoch [94/700], Train Loss: 3.78692Mean Accuracy: 0.9922, Test Loss: 1.77743
# Epoch [95/700], Train Loss: 3.86432Mean Accuracy: 0.9896, Test Loss: 1.96934
# Epoch [96/700], Train Loss: 3.94601Mean Accuracy: 0.9908, Test Loss: 1.86608
# Epoch [97/700], Train Loss: 3.76894Mean Accuracy: 0.9921, Test Loss: 2.14943
# Epoch [98/700], Train Loss: 3.60714Mean Accuracy: 0.9922, Test Loss: 2.20345
# Epoch [99/700], Train Loss: 3.72898Mean Accuracy: 0.9917, Test Loss: 1.95275
# Epoch [100/700], Train Loss: 3.62193Mean Accuracy: 0.9912, Test Loss: 2.46733
# Epoch [101/700], Train Loss: 4.05760Mean Accuracy: 0.9913, Test Loss: 1.89738
# Epoch [102/700], Train Loss: 3.79999Mean Accuracy: 0.9898, Test Loss: 2.50916
# Epoch [103/700], Train Loss: 4.50087Mean Accuracy: 0.9918, Test Loss: 1.81147
# Epoch [104/700], Train Loss: 3.77258Mean Accuracy: 0.9926, Test Loss: 1.75058
# Epoch [105/700], Train Loss: 4.10573Mean Accuracy: 0.9886, Test Loss: 1.69935
# Epoch [106/700], Train Loss: 3.75098Mean Accuracy: 0.9904, Test Loss: 2.13801
# Epoch [107/700], Train Loss: 3.62454Mean Accuracy: 0.9910, Test Loss: 2.22344
# Epoch [108/700], Train Loss: 4.33860Mean Accuracy: 0.9919, Test Loss: 1.69859
# Epoch [109/700], Train Loss: 3.96127Mean Accuracy: 0.9896, Test Loss: 2.15466
# Epoch [110/700], Train Loss: 3.89784Mean Accuracy: 0.9921, Test Loss: 1.91310
# Epoch [111/700], Train Loss: 3.42288Mean Accuracy: 0.9926, Test Loss: 1.95899
# Epoch [112/700], Train Loss: 3.57333Mean Accuracy: 0.9908, Test Loss: 1.90521
# Epoch [113/700], Train Loss: 3.62168Mean Accuracy: 0.9925, Test Loss: 2.13059
# Epoch [114/700], Train Loss: 3.48858Mean Accuracy: 0.9912, Test Loss: 2.07397
# Epoch [115/700], Train Loss: 3.79110Mean Accuracy: 0.9921, Test Loss: 2.17287
# Epoch [116/700], Train Loss: 3.33050Mean Accuracy: 0.9929, Test Loss: 2.16854
# Epoch [117/700], Train Loss: 3.16522Mean Accuracy: 0.9925, Test Loss: 2.36711
# Epoch [118/700], Train Loss: 3.24186Mean Accuracy: 0.9922, Test Loss: 2.53341
# Epoch [119/700], Train Loss: 2.93875Mean Accuracy: 0.9925, Test Loss: 2.24065
# Epoch [120/700], Train Loss: 3.73519Mean Accuracy: 0.9924, Test Loss: 2.25927
# Epoch [121/700], Train Loss: 2.85895Mean Accuracy: 0.9816, Test Loss: 4.07039
# Epoch [122/700], Train Loss: 5.33114Mean Accuracy: 0.9849, Test Loss: 2.31836
# Epoch [123/700], Train Loss: 4.91544Mean Accuracy: 0.9854, Test Loss: 2.28474
# Epoch [124/700], Train Loss: 4.85706Mean Accuracy: 0.9853, Test Loss: 2.24190
# Epoch [125/700], Train Loss: 4.81304Mean Accuracy: 0.9851, Test Loss: 2.24833
# Epoch [126/700], Train Loss: 4.69995Mean Accuracy: 0.9859, Test Loss: 2.35560
# Epoch [127/700], Train Loss: 4.50062Mean Accuracy: 0.9880, Test Loss: 2.52989
# Epoch [128/700], Train Loss: 4.37894Mean Accuracy: 0.9896, Test Loss: 2.03377
# Epoch [129/700], Train Loss: 4.33890Mean Accuracy: 0.9894, Test Loss: 2.01145
# Epoch [130/700], Train Loss: 4.34789Mean Accuracy: 0.9906, Test Loss: 1.84475
# Epoch [131/700], Train Loss: 4.21677Mean Accuracy: 0.9867, Test Loss: 2.56183
# Epoch [132/700], Train Loss: 4.49027Mean Accuracy: 0.9909, Test Loss: 1.88113
# Epoch [133/700], Train Loss: 4.04873Mean Accuracy: 0.9904, Test Loss: 1.79627
# Epoch [134/700], Train Loss: 4.09741Mean Accuracy: 0.9913, Test Loss: 1.81573
# Epoch [135/700], Train Loss: 3.91091Mean Accuracy: 0.9913, Test Loss: 2.06555
# Epoch [136/700], Train Loss: 3.77236Mean Accuracy: 0.9919, Test Loss: 3.05349
# Epoch [137/700], Train Loss: 4.05861Mean Accuracy: 0.9919, Test Loss: 2.10227
# Epoch [138/700], Train Loss: 3.56723Mean Accuracy: 0.9895, Test Loss: 2.05187
# Epoch [139/700], Train Loss: 4.12496Mean Accuracy: 0.9910, Test Loss: 2.03366
# Epoch [140/700], Train Loss: 3.99616Mean Accuracy: 0.9920, Test Loss: 2.02041
# Epoch [141/700], Train Loss: 3.61120Mean Accuracy: 0.9925, Test Loss: 1.99164
# Epoch [142/700], Train Loss: 3.05353Mean Accuracy: 0.9908, Test Loss: 2.85871
# Epoch [143/700], Train Loss: 4.31997Mean Accuracy: 0.9907, Test Loss: 1.95492
# Epoch [144/700], Train Loss: 3.45846Mean Accuracy: 0.9926, Test Loss: 2.12493
# Epoch [145/700], Train Loss: 2.87044Mean Accuracy: 0.9917, Test Loss: 2.23681
# Epoch [146/700], Train Loss: 3.95827Mean Accuracy: 0.9919, Test Loss: 1.79602
# Epoch [147/700], Train Loss: 3.32232Mean Accuracy: 0.9927, Test Loss: 1.76049
# Epoch [148/700], Train Loss: 3.81016Mean Accuracy: 0.9922, Test Loss: 2.11132
# Epoch [149/700], Train Loss: 3.49558Mean Accuracy: 0.9915, Test Loss: 1.92619
# Epoch [150/700], Train Loss: 3.37434Mean Accuracy: 0.9920, Test Loss: 2.01508
# Epoch [151/700], Train Loss: 3.54806Mean Accuracy: 0.9908, Test Loss: 1.76923
# Epoch [152/700], Train Loss: 3.48236Mean Accuracy: 0.9926, Test Loss: 2.02308
# Epoch [153/700], Train Loss: 3.33455Mean Accuracy: 0.9924, Test Loss: 1.92860
# Epoch [154/700], Train Loss: 2.65037Mean Accuracy: 0.9930, Test Loss: 2.21993
# Epoch [155/700], Train Loss: 2.31146Mean Accuracy: 0.9931, Test Loss: 2.07223
# Epoch [156/700], Train Loss: 2.86152Mean Accuracy: 0.9922, Test Loss: 1.96552
# Epoch [157/700], Train Loss: 3.12385Mean Accuracy: 0.9914, Test Loss: 2.14371
# Epoch [158/700], Train Loss: 3.12462Mean Accuracy: 0.9918, Test Loss: 1.84608
# Epoch [159/700], Train Loss: 3.06403Mean Accuracy: 0.9921, Test Loss: 1.84752
# Epoch [160/700], Train Loss: 3.37561Mean Accuracy: 0.9919, Test Loss: 2.05232
# Epoch [161/700], Train Loss: 3.97205Mean Accuracy: 0.9925, Test Loss: 1.84734
# Epoch [162/700], Train Loss: 2.44264Mean Accuracy: 0.9926, Test Loss: 2.16602
# Epoch [163/700], Train Loss: 2.86006Mean Accuracy: 0.9928, Test Loss: 2.35547
# Epoch [164/700], Train Loss: 2.53735Mean Accuracy: 0.9931, Test Loss: 1.99528
# Epoch [165/700], Train Loss: 2.12083Mean Accuracy: 0.9903, Test Loss: 2.71810
# Epoch [166/700], Train Loss: 4.67368Mean Accuracy: 0.9909, Test Loss: 2.56686
# Epoch [167/700], Train Loss: 3.59253Mean Accuracy: 0.9924, Test Loss: 2.18569
# Epoch [168/700], Train Loss: 2.60087Mean Accuracy: 0.9929, Test Loss: 2.05510
# Epoch [169/700], Train Loss: 3.79529Mean Accuracy: 0.9923, Test Loss: 2.10017
# Epoch [170/700], Train Loss: 3.21737Mean Accuracy: 0.9925, Test Loss: 2.01996
# Epoch [171/700], Train Loss: 2.88510Mean Accuracy: 0.9925, Test Loss: 1.91741
# Epoch [172/700], Train Loss: 2.47214Mean Accuracy: 0.9917, Test Loss: 1.92168
# Epoch [173/700], Train Loss: 2.70856Mean Accuracy: 0.9928, Test Loss: 2.10532
# Epoch [174/700], Train Loss: 2.96337Mean Accuracy: 0.9922, Test Loss: 1.92340
# Epoch [175/700], Train Loss: 3.02971Mean Accuracy: 0.9931, Test Loss: 1.79127
# Epoch [176/700], Train Loss: 1.91225Mean Accuracy: 0.9934, Test Loss: 1.78502
# Epoch [177/700], Train Loss: 2.26012Mean Accuracy: 0.9906, Test Loss: 2.42417
# Epoch [178/700], Train Loss: 2.62167Mean Accuracy: 0.9927, Test Loss: 2.16922
# Epoch [179/700], Train Loss: 2.05519Mean Accuracy: 0.9927, Test Loss: 2.09565
# Epoch [180/700], Train Loss: 1.95870Mean Accuracy: 0.9907, Test Loss: 2.99032
# Epoch [181/700], Train Loss: 3.51818Mean Accuracy: 0.9929, Test Loss: 1.91140
# Epoch [182/700], Train Loss: 2.85357Mean Accuracy: 0.9923, Test Loss: 2.05253
# Epoch [183/700], Train Loss: 1.97366Mean Accuracy: 0.9934, Test Loss: 1.88391
# Epoch [184/700], Train Loss: 1.70765Mean Accuracy: 0.9931, Test Loss: 1.86592
# Epoch [185/700], Train Loss: 3.02137Mean Accuracy: 0.9923, Test Loss: 2.50664
# Epoch [186/700], Train Loss: 2.68851Mean Accuracy: 0.9924, Test Loss: 2.23686
# Epoch [187/700], Train Loss: 1.93315Mean Accuracy: 0.9929, Test Loss: 2.00711
# Epoch [188/700], Train Loss: 2.22059Mean Accuracy: 0.9930, Test Loss: 2.06891
# Epoch [189/700], Train Loss: 1.89597Mean Accuracy: 0.9928, Test Loss: 2.11659
# Epoch [190/700], Train Loss: 2.94052Mean Accuracy: 0.9933, Test Loss: 2.01505
# Epoch [191/700], Train Loss: 1.45676Mean Accuracy: 0.9935, Test Loss: 1.91496
# Epoch [192/700], Train Loss: 1.57324Mean Accuracy: 0.9926, Test Loss: 2.01145
# Epoch [193/700], Train Loss: 2.20043Mean Accuracy: 0.9868, Test Loss: 2.50890
# Epoch [194/700], Train Loss: 4.12669Mean Accuracy: 0.9914, Test Loss: 2.48794
# Epoch [195/700], Train Loss: 2.92606Mean Accuracy: 0.9911, Test Loss: 2.03592
# Epoch [196/700], Train Loss: 2.83756Mean Accuracy: 0.9918, Test Loss: 2.50166
# Epoch [197/700], Train Loss: 2.68631Mean Accuracy: 0.9923, Test Loss: 3.60641
# Epoch [198/700], Train Loss: 2.95517Mean Accuracy: 0.9931, Test Loss: 2.48817
# Epoch [199/700], Train Loss: 2.98601Mean Accuracy: 0.9904, Test Loss: 4.08916
# Epoch [200/700], Train Loss: 3.33632Mean Accuracy: 0.9927, Test Loss: 1.98941
# Epoch [201/700], Train Loss: 2.45991Mean Accuracy: 0.9929, Test Loss: 1.86468
# Epoch [202/700], Train Loss: 2.12194Mean Accuracy: 0.9927, Test Loss: 2.54064
# Epoch [203/700], Train Loss: 3.82429Mean Accuracy: 0.9927, Test Loss: 1.74524
# Epoch [204/700], Train Loss: 3.48223Mean Accuracy: 0.9927, Test Loss: 2.60674
# Epoch [205/700], Train Loss: 3.39874Mean Accuracy: 0.9927, Test Loss: 1.99576
# Epoch [206/700], Train Loss: 2.52150Mean Accuracy: 0.9925, Test Loss: 2.10305
# Epoch [207/700], Train Loss: 2.78678Mean Accuracy: 0.9917, Test Loss: 2.08007
# Epoch [208/700], Train Loss: 2.07600Mean Accuracy: 0.9925, Test Loss: 2.04603
# Epoch [209/700], Train Loss: 1.85473Mean Accuracy: 0.9916, Test Loss: 2.42459
# Epoch [210/700], Train Loss: 3.90276Mean Accuracy: 0.9921, Test Loss: 2.93397
# Epoch [211/700], Train Loss: 2.87421Mean Accuracy: 0.9918, Test Loss: 2.90571
# Epoch [212/700], Train Loss: 3.27470Mean Accuracy: 0.9926, Test Loss: 2.17109
# Epoch [213/700], Train Loss: 2.21957Mean Accuracy: 0.9932, Test Loss: 1.91611
# Epoch [214/700], Train Loss: 1.61134Mean Accuracy: 0.9933, Test Loss: 1.80508
# Epoch [215/700], Train Loss: 1.21191Mean Accuracy: 0.9934, Test Loss: 1.89514
# Epoch [216/700], Train Loss: 1.12261Mean Accuracy: 0.9935, Test Loss: 1.73488
# Epoch [217/700], Train Loss: 1.95553Mean Accuracy: 0.9921, Test Loss: 2.96043
# Epoch [218/700], Train Loss: 2.46780Mean Accuracy: 0.9920, Test Loss: 2.78276
# Epoch [219/700], Train Loss: 3.86049Mean Accuracy: 0.9920, Test Loss: 2.29994
# Epoch [220/700], Train Loss: 2.61217Mean Accuracy: 0.9917, Test Loss: 2.40191
# Epoch [221/700], Train Loss: 1.69082Mean Accuracy: 0.9928, Test Loss: 2.04630
# Epoch [222/700], Train Loss: 1.54935Mean Accuracy: 0.9932, Test Loss: 2.14614
# Epoch [223/700], Train Loss: 1.33007Mean Accuracy: 0.9931, Test Loss: 1.97614
# Epoch [224/700], Train Loss: 2.46010Mean Accuracy: 0.9924, Test Loss: 2.22221
# Epoch [225/700], Train Loss: 3.25207Mean Accuracy: 0.9928, Test Loss: 2.79374
# Epoch [226/700], Train Loss: 2.06665Mean Accuracy: 0.9921, Test Loss: 2.06072
# Epoch [227/700], Train Loss: 1.38069Mean Accuracy: 0.9933, Test Loss: 1.93815
# Epoch [228/700], Train Loss: 0.92880Mean Accuracy: 0.9934, Test Loss: 1.86681
# Epoch [229/700], Train Loss: 0.86302Mean Accuracy: 0.9934, Test Loss: 1.83714
# Epoch [230/700], Train Loss: 0.86292Mean Accuracy: 0.9936, Test Loss: 1.77362
# Epoch [231/700], Train Loss: 1.17626Mean Accuracy: 0.9931, Test Loss: 1.80987
# Epoch [232/700], Train Loss: 1.04643Mean Accuracy: 0.9931, Test Loss: 1.83755
# Epoch [233/700], Train Loss: 2.61743Mean Accuracy: 0.9931, Test Loss: 1.83763
# Epoch [234/700], Train Loss: 1.55612Mean Accuracy: 0.9933, Test Loss: 2.00886
# Epoch [235/700], Train Loss: 1.51985Mean Accuracy: 0.9933, Test Loss: 1.88041
# Epoch [236/700], Train Loss: 0.87029Mean Accuracy: 0.9934, Test Loss: 1.78253
# Epoch [237/700], Train Loss: 0.84750Mean Accuracy: 0.9926, Test Loss: 1.80380
# Epoch [238/700], Train Loss: 1.43344Mean Accuracy: 0.9923, Test Loss: 2.41238
# Epoch [239/700], Train Loss: 3.56930Mean Accuracy: 0.9873, Test Loss: 2.24197
# Epoch [240/700], Train Loss: 2.33348Mean Accuracy: 0.9926, Test Loss: 1.97055
# Epoch [241/700], Train Loss: 1.34891Mean Accuracy: 0.9932, Test Loss: 1.79055
# Epoch [242/700], Train Loss: 1.08641Mean Accuracy: 0.9930, Test Loss: 1.95654
# Epoch [243/700], Train Loss: 0.86404Mean Accuracy: 0.9934, Test Loss: 1.71368
# Epoch [244/700], Train Loss: 0.73917Mean Accuracy: 0.9937, Test Loss: 1.72124
# Epoch [245/700], Train Loss: 0.67518Mean Accuracy: 0.9936, Test Loss: 1.67787
# Epoch [246/700], Train Loss: 0.64129Mean Accuracy: 0.9936, Test Loss: 1.69231
# Epoch [247/700], Train Loss: 0.62843Mean Accuracy: 0.9936, Test Loss: 1.69054
# Epoch [248/700], Train Loss: 0.60798Mean Accuracy: 0.9936, Test Loss: 1.68594
# Epoch [249/700], Train Loss: 0.61640Mean Accuracy: 0.9936, Test Loss: 1.69037
# Epoch [250/700], Train Loss: 0.61439Mean Accuracy: 0.9936, Test Loss: 1.70296
# Epoch [251/700], Train Loss: 0.62915Mean Accuracy: 0.9935, Test Loss: 1.72564
# Epoch [252/700], Train Loss: 0.59710Mean Accuracy: 0.9936, Test Loss: 1.71196
# Epoch [253/700], Train Loss: 0.58024Mean Accuracy: 0.9936, Test Loss: 1.69882
# Epoch [254/700], Train Loss: 0.56023Mean Accuracy: 0.9936, Test Loss: 1.70833
# Epoch [255/700], Train Loss: 0.56514Mean Accuracy: 0.9936, Test Loss: 1.72832
# Epoch [256/700], Train Loss: 0.55299Mean Accuracy: 0.9936, Test Loss: 1.71172
# Epoch [257/700], Train Loss: 0.55091Mean Accuracy: 0.9936, Test Loss: 1.73568
# Epoch [258/700], Train Loss: 0.55460Mean Accuracy: 0.9936, Test Loss: 1.73422
# Epoch [259/700], Train Loss: 0.52954Mean Accuracy: 0.9934, Test Loss: 1.78291
# Epoch [260/700], Train Loss: 0.55158Mean Accuracy: 0.9937, Test Loss: 1.74113
# Epoch [261/700], Train Loss: 0.98011Mean Accuracy: 0.9931, Test Loss: 1.82790
# Epoch [262/700], Train Loss: 0.93279Mean Accuracy: 0.9934, Test Loss: 1.83896
# Epoch [263/700], Train Loss: 0.72255Mean Accuracy: 0.9935, Test Loss: 1.64831
# Epoch [264/700], Train Loss: 1.00266Mean Accuracy: 0.9935, Test Loss: 1.89830
# Epoch [265/700], Train Loss: 0.62056Mean Accuracy: 0.9935, Test Loss: 1.78321
# Epoch [266/700], Train Loss: 0.60799Mean Accuracy: 0.9935, Test Loss: 1.75281
# Epoch [267/700], Train Loss: 0.51302Mean Accuracy: 0.9936, Test Loss: 1.74899
# Epoch [268/700], Train Loss: 0.49308Mean Accuracy: 0.9936, Test Loss: 1.77719
# Epoch [269/700], Train Loss: 0.49815Mean Accuracy: 0.9936, Test Loss: 1.77174
# Epoch [270/700], Train Loss: 0.49161Mean Accuracy: 0.9935, Test Loss: 1.79906
# Epoch [271/700], Train Loss: 0.95020Mean Accuracy: 0.9925, Test Loss: 3.67885
# Epoch [272/700], Train Loss: 1.56724Mean Accuracy: 0.9931, Test Loss: 1.88686
# Epoch [273/700], Train Loss: 2.09866Mean Accuracy: 0.9848, Test Loss: 2.83070
# Epoch [274/700], Train Loss: 3.46614Mean Accuracy: 0.9915, Test Loss: 2.11557
# Epoch [275/700], Train Loss: 4.36278Mean Accuracy: 0.9914, Test Loss: 1.97594
# Epoch [276/700], Train Loss: 2.70872Mean Accuracy: 0.9931, Test Loss: 1.90405
# Epoch [277/700], Train Loss: 1.33582Mean Accuracy: 0.9931, Test Loss: 1.78581
# Epoch [278/700], Train Loss: 0.97332Mean Accuracy: 0.9930, Test Loss: 1.75559
# Epoch [279/700], Train Loss: 2.75891Mean Accuracy: 0.9926, Test Loss: 2.09615
# Epoch [280/700], Train Loss: 1.66806Mean Accuracy: 0.9932, Test Loss: 1.75517
# Epoch [281/700], Train Loss: 1.01765Mean Accuracy: 0.9935, Test Loss: 1.66467
# Epoch [282/700], Train Loss: 1.09239Mean Accuracy: 0.9933, Test Loss: 1.74148
# Epoch [283/700], Train Loss: 1.71680Mean Accuracy: 0.9929, Test Loss: 1.91586
# Epoch [284/700], Train Loss: 0.93282Mean Accuracy: 0.9926, Test Loss: 2.05811
# Epoch [285/700], Train Loss: 2.49689Mean Accuracy: 0.9929, Test Loss: 2.08216
# Epoch [286/700], Train Loss: 0.82706Mean Accuracy: 0.9936, Test Loss: 1.75901
# Epoch [287/700], Train Loss: 0.58545Mean Accuracy: 0.9935, Test Loss: 1.70179
# Epoch [288/700], Train Loss: 1.08491Mean Accuracy: 0.9923, Test Loss: 1.87097
# Epoch [289/700], Train Loss: 0.86249Mean Accuracy: 0.9933, Test Loss: 1.71423
# Epoch [290/700], Train Loss: 0.53866Mean Accuracy: 0.9936, Test Loss: 1.70704
# Epoch [291/700], Train Loss: 0.59851Mean Accuracy: 0.9937, Test Loss: 1.73891
# Epoch [292/700], Train Loss: 0.47640Mean Accuracy: 0.9937, Test Loss: 1.68034
# Epoch [293/700], Train Loss: 0.40776Mean Accuracy: 0.9937, Test Loss: 1.68160
# Epoch [294/700], Train Loss: 0.37565Mean Accuracy: 0.9937, Test Loss: 1.69739
# Epoch [295/700], Train Loss: 0.37454Mean Accuracy: 0.9936, Test Loss: 1.66157
# Epoch [296/700], Train Loss: 0.35829Mean Accuracy: 0.9936, Test Loss: 1.66275
# Epoch [297/700], Train Loss: 0.36403Mean Accuracy: 0.9936, Test Loss: 1.75488
# Epoch [298/700], Train Loss: 0.34781Mean Accuracy: 0.9937, Test Loss: 1.67995
# Epoch [299/700], Train Loss: 0.33504Mean Accuracy: 0.9936, Test Loss: 1.70513
# Epoch [300/700], Train Loss: 0.33977Mean Accuracy: 0.9936, Test Loss: 1.68099
# Epoch [301/700], Train Loss: 0.34223Mean Accuracy: 0.9936, Test Loss: 1.69861
# Epoch [302/700], Train Loss: 0.33506Mean Accuracy: 0.9937, Test Loss: 1.69830
# Epoch [303/700], Train Loss: 0.31671Mean Accuracy: 0.9936, Test Loss: 1.75627
# Epoch [304/700], Train Loss: 0.36489Mean Accuracy: 0.9935, Test Loss: 1.71484
# Epoch [305/700], Train Loss: 0.38626Mean Accuracy: 0.9935, Test Loss: 1.78298
# Epoch [306/700], Train Loss: 0.48283Mean Accuracy: 0.9930, Test Loss: 1.90772
# Epoch [307/700], Train Loss: 1.83416Mean Accuracy: 0.9926, Test Loss: 2.23396
# Epoch [308/700], Train Loss: 2.68226Mean Accuracy: 0.9925, Test Loss: 2.09981
# Epoch [309/700], Train Loss: 2.59623Mean Accuracy: 0.9932, Test Loss: 1.98058
# Epoch [310/700], Train Loss: 1.61155Mean Accuracy: 0.9925, Test Loss: 1.79084
# Epoch [311/700], Train Loss: 1.67222Mean Accuracy: 0.9933, Test Loss: 1.81780
# Epoch [312/700], Train Loss: 0.74502Mean Accuracy: 0.9936, Test Loss: 1.72595
# Epoch [313/700], Train Loss: 0.51962Mean Accuracy: 0.9933, Test Loss: 1.79304
# Epoch [314/700], Train Loss: 0.40508Mean Accuracy: 0.9936, Test Loss: 1.70344
# Epoch [315/700], Train Loss: 0.36910Mean Accuracy: 0.9936, Test Loss: 1.66480
# Epoch [316/700], Train Loss: 0.31274Mean Accuracy: 0.9937, Test Loss: 1.68050
# Epoch [317/700], Train Loss: 0.29996Mean Accuracy: 0.9937, Test Loss: 1.72824
# Epoch [318/700], Train Loss: 0.27929Mean Accuracy: 0.9937, Test Loss: 1.69291
# Epoch [319/700], Train Loss: 0.26815Mean Accuracy: 0.9936, Test Loss: 1.69624
# Epoch [320/700], Train Loss: 0.26252Mean Accuracy: 0.9936, Test Loss: 1.69625
# Epoch [321/700], Train Loss: 0.24882Mean Accuracy: 0.9937, Test Loss: 1.71120
# Epoch [322/700], Train Loss: 0.26642Mean Accuracy: 0.9937, Test Loss: 1.71325
# Epoch [323/700], Train Loss: 0.24689Mean Accuracy: 0.9937, Test Loss: 1.73273
# Epoch [324/700], Train Loss: 0.27956Mean Accuracy: 0.9937, Test Loss: 1.70667
# Epoch [325/700], Train Loss: 0.26422Mean Accuracy: 0.9936, Test Loss: 1.73459
# Epoch [326/700], Train Loss: 0.24807Mean Accuracy: 0.9935, Test Loss: 1.71269
# Epoch [327/700], Train Loss: 0.41556Mean Accuracy: 0.9935, Test Loss: 1.75413
# Epoch [328/700], Train Loss: 1.61189Mean Accuracy: 0.9925, Test Loss: 3.46701
# Epoch [329/700], Train Loss: 2.98861Mean Accuracy: 0.9930, Test Loss: 2.03941
# Epoch [330/700], Train Loss: 1.31934Mean Accuracy: 0.9923, Test Loss: 2.26177
# Epoch [331/700], Train Loss: 1.26660Mean Accuracy: 0.9924, Test Loss: 2.07867
# Epoch [332/700], Train Loss: 1.17614Mean Accuracy: 0.9930, Test Loss: 1.72824
# Epoch [333/700], Train Loss: 0.60700Mean Accuracy: 0.9935, Test Loss: 1.72963
# Epoch [334/700], Train Loss: 0.37851Mean Accuracy: 0.9937, Test Loss: 1.76385
# Epoch [335/700], Train Loss: 0.30620Mean Accuracy: 0.9937, Test Loss: 1.76612
# Epoch [336/700], Train Loss: 0.26818Mean Accuracy: 0.9937, Test Loss: 1.69996
# Epoch [337/700], Train Loss: 0.24421Mean Accuracy: 0.9936, Test Loss: 1.71185
# Epoch [338/700], Train Loss: 0.23503Mean Accuracy: 0.9936, Test Loss: 1.71804
# Epoch [339/700], Train Loss: 0.24140Mean Accuracy: 0.9936, Test Loss: 1.77235
# Epoch [340/700], Train Loss: 0.29329Mean Accuracy: 0.9936, Test Loss: 1.83285
# Epoch [341/700], Train Loss: 0.27562Mean Accuracy: 0.9936, Test Loss: 1.73856
# Epoch [342/700], Train Loss: 0.23509Mean Accuracy: 0.9936, Test Loss: 1.70950
# Epoch [343/700], Train Loss: 0.25857Mean Accuracy: 0.9936, Test Loss: 1.70598
# Epoch [344/700], Train Loss: 0.24088Mean Accuracy: 0.9936, Test Loss: 1.76247
# Epoch [345/700], Train Loss: 0.25665Mean Accuracy: 0.9936, Test Loss: 1.72480
# Epoch [346/700], Train Loss: 0.21987Mean Accuracy: 0.9936, Test Loss: 1.74828
# Epoch [347/700], Train Loss: 0.20925Mean Accuracy: 0.9936, Test Loss: 1.73697
# Epoch [348/700], Train Loss: 0.19912Mean Accuracy: 0.9936, Test Loss: 1.72379
# Epoch [349/700], Train Loss: 0.18129Mean Accuracy: 0.9937, Test Loss: 1.71453
# Epoch [350/700], Train Loss: 0.17974Mean Accuracy: 0.9937, Test Loss: 1.72329
# Epoch [351/700], Train Loss: 0.17485Mean Accuracy: 0.9936, Test Loss: 1.72107
# Epoch [352/700], Train Loss: 0.16919Mean Accuracy: 0.9936, Test Loss: 1.72300
# Epoch [353/700], Train Loss: 0.16526Mean Accuracy: 0.9937, Test Loss: 1.72822
# Epoch [354/700], Train Loss: 0.18239Mean Accuracy: 0.9935, Test Loss: 1.73825
# Epoch [355/700], Train Loss: 0.20971Mean Accuracy: 0.9935, Test Loss: 1.80053
# Epoch [356/700], Train Loss: 0.24560Mean Accuracy: 0.9935, Test Loss: 1.72077
# Epoch [357/700], Train Loss: 0.25475Mean Accuracy: 0.9935, Test Loss: 1.74129
# Epoch [358/700], Train Loss: 0.19667Mean Accuracy: 0.9935, Test Loss: 1.80611
# Epoch [359/700], Train Loss: 0.25088Mean Accuracy: 0.9934, Test Loss: 1.78010
# Epoch [360/700], Train Loss: 0.20472Mean Accuracy: 0.9935, Test Loss: 1.76684
# Epoch [361/700], Train Loss: 0.18279Mean Accuracy: 0.9935, Test Loss: 1.77717
# Epoch [362/700], Train Loss: 0.17353Mean Accuracy: 0.9935, Test Loss: 1.73040
# Epoch [363/700], Train Loss: 0.21389Mean Accuracy: 0.9935, Test Loss: 1.72770
# Epoch [364/700], Train Loss: 0.19103Mean Accuracy: 0.9935, Test Loss: 1.73345
# Epoch [365/700], Train Loss: 0.16896Mean Accuracy: 0.9936, Test Loss: 1.76926
# Epoch [366/700], Train Loss: 0.16949Mean Accuracy: 0.9935, Test Loss: 1.76102
# Epoch [367/700], Train Loss: 0.16902Mean Accuracy: 0.9936, Test Loss: 1.74031
# Epoch [368/700], Train Loss: 0.16281Mean Accuracy: 0.9936, Test Loss: 1.75035
# Epoch [369/700], Train Loss: 0.14824Mean Accuracy: 0.9936, Test Loss: 1.74009
# Epoch [370/700], Train Loss: 0.14298Mean Accuracy: 0.9936, Test Loss: 1.73099
# Epoch [371/700], Train Loss: 0.14163Mean Accuracy: 0.9935, Test Loss: 1.75448
# Epoch [372/700], Train Loss: 0.14758Mean Accuracy: 0.9936, Test Loss: 1.75096
# Epoch [373/700], Train Loss: 0.14314Mean Accuracy: 0.9935, Test Loss: 1.74557
# Epoch [374/700], Train Loss: 0.17884Mean Accuracy: 0.9935, Test Loss: 1.74697
# Epoch [375/700], Train Loss: 0.14904Mean Accuracy: 0.9936, Test Loss: 1.74019
# Epoch [376/700], Train Loss: 0.14007Mean Accuracy: 0.9936, Test Loss: 1.73774
# Epoch [377/700], Train Loss: 0.13273Mean Accuracy: 0.9935, Test Loss: 1.74038
# Epoch [378/700], Train Loss: 0.13212Mean Accuracy: 0.9936, Test Loss: 1.74308
# Epoch [379/700], Train Loss: 0.13090Mean Accuracy: 0.9936, Test Loss: 1.75687
# Epoch [380/700], Train Loss: 0.12936Mean Accuracy: 0.9935, Test Loss: 1.74782
# Epoch [381/700], Train Loss: 0.13948Mean Accuracy: 0.9935, Test Loss: 1.74335
# Epoch [382/700], Train Loss: 0.13492Mean Accuracy: 0.9936, Test Loss: 1.75228
# Epoch [383/700], Train Loss: 0.12725Mean Accuracy: 0.9936, Test Loss: 1.74802
# Epoch [384/700], Train Loss: 0.12664Mean Accuracy: 0.9936, Test Loss: 1.75059
# Epoch [385/700], Train Loss: 0.12850Mean Accuracy: 0.9936, Test Loss: 1.76170
# Epoch [386/700], Train Loss: 0.13198Mean Accuracy: 0.9935, Test Loss: 1.77212
# Epoch [387/700], Train Loss: 0.12525Mean Accuracy: 0.9935, Test Loss: 1.78241
# Epoch [388/700], Train Loss: 0.12673Mean Accuracy: 0.9935, Test Loss: 1.74455
# Epoch [389/700], Train Loss: 0.12234Mean Accuracy: 0.9935, Test Loss: 1.76487
# Epoch [390/700], Train Loss: 0.24259Mean Accuracy: 0.9932, Test Loss: 1.93282
# Epoch [391/700], Train Loss: 0.55840Mean Accuracy: 0.9931, Test Loss: 1.76825
# Epoch [392/700], Train Loss: 0.47718Mean Accuracy: 0.9933, Test Loss: 1.81554
# Epoch [393/700], Train Loss: 0.35787Mean Accuracy: 0.9933, Test Loss: 1.81619
# Epoch [394/700], Train Loss: 0.39149Mean Accuracy: 0.9934, Test Loss: 1.73595
# Epoch [395/700], Train Loss: 0.29530Mean Accuracy: 0.9935, Test Loss: 1.74130
# Epoch [396/700], Train Loss: 0.25301Mean Accuracy: 0.9936, Test Loss: 1.73121
# Epoch [397/700], Train Loss: 0.23707Mean Accuracy: 0.9936, Test Loss: 1.72486
# Epoch [398/700], Train Loss: 0.19924Mean Accuracy: 0.9935, Test Loss: 1.72922
# Epoch [399/700], Train Loss: 0.20579Mean Accuracy: 0.9935, Test Loss: 1.73114
# Epoch [400/700], Train Loss: 0.20848Mean Accuracy: 0.9933, Test Loss: 1.77694
# Epoch [401/700], Train Loss: 0.22037Mean Accuracy: 0.9934, Test Loss: 1.70874
# Epoch [402/700], Train Loss: 0.21806Mean Accuracy: 0.9935, Test Loss: 1.81098
# Epoch [403/700], Train Loss: 0.16053Mean Accuracy: 0.9936, Test Loss: 1.69305
# Epoch [404/700], Train Loss: 0.13854Mean Accuracy: 0.9935, Test Loss: 1.75776
# Epoch [405/700], Train Loss: 0.12286Mean Accuracy: 0.9936, Test Loss: 1.70852
# Epoch [406/700], Train Loss: 0.11866Mean Accuracy: 0.9936, Test Loss: 1.73022
# Epoch [407/700], Train Loss: 0.13321Mean Accuracy: 0.9932, Test Loss: 1.85822
# Epoch [408/700], Train Loss: 0.15799Mean Accuracy: 0.9936, Test Loss: 1.73555
# Epoch [409/700], Train Loss: 0.14506Mean Accuracy: 0.9936, Test Loss: 1.73548
# Epoch [410/700], Train Loss: 0.12862Mean Accuracy: 0.9935, Test Loss: 1.76635
# Epoch [411/700], Train Loss: 0.11474Mean Accuracy: 0.9935, Test Loss: 1.73084
# Epoch [412/700], Train Loss: 0.11041Mean Accuracy: 0.9935, Test Loss: 1.73467
# Epoch [413/700], Train Loss: 0.10796Mean Accuracy: 0.9935, Test Loss: 1.72626
# Epoch [414/700], Train Loss: 0.10543Mean Accuracy: 0.9935, Test Loss: 1.72886
# Epoch [415/700], Train Loss: 0.10669Mean Accuracy: 0.9935, Test Loss: 1.73015
# Epoch [416/700], Train Loss: 0.10173Mean Accuracy: 0.9935, Test Loss: 1.73089
# Epoch [417/700], Train Loss: 0.10703Mean Accuracy: 0.9934, Test Loss: 1.73757
# Epoch [418/700], Train Loss: 0.11258Mean Accuracy: 0.9935, Test Loss: 1.74341
# Epoch [419/700], Train Loss: 0.11032Mean Accuracy: 0.9935, Test Loss: 1.72604
# Epoch [420/700], Train Loss: 0.10676Mean Accuracy: 0.9935, Test Loss: 1.71924
# Epoch [421/700], Train Loss: 0.10314Mean Accuracy: 0.9935, Test Loss: 1.73284
# Epoch [422/700], Train Loss: 0.10044Mean Accuracy: 0.9935, Test Loss: 1.73610
# Epoch [423/700], Train Loss: 0.10067Mean Accuracy: 0.9935, Test Loss: 1.73222
# Epoch [424/700], Train Loss: 0.10078Mean Accuracy: 0.9935, Test Loss: 1.74521
# Epoch [425/700], Train Loss: 0.10522Mean Accuracy: 0.9935, Test Loss: 1.73061
# Epoch [426/700], Train Loss: 0.10652Mean Accuracy: 0.9935, Test Loss: 1.74562
# Epoch [427/700], Train Loss: 0.09853Mean Accuracy: 0.9935, Test Loss: 1.74626
# Epoch [428/700], Train Loss: 0.09499Mean Accuracy: 0.9935, Test Loss: 1.74675
# Epoch [429/700], Train Loss: 0.09507Mean Accuracy: 0.9934, Test Loss: 1.77438
# Epoch [430/700], Train Loss: 0.09836Mean Accuracy: 0.9935, Test Loss: 1.73366
# Epoch [431/700], Train Loss: 0.10037Mean Accuracy: 0.9935, Test Loss: 1.74526
# Epoch [432/700], Train Loss: 0.09412Mean Accuracy: 0.9935, Test Loss: 1.74157
# Epoch [433/700], Train Loss: 0.09238Mean Accuracy: 0.9935, Test Loss: 1.74621
# Epoch [434/700], Train Loss: 0.09385Mean Accuracy: 0.9935, Test Loss: 1.76088
# Epoch [435/700], Train Loss: 0.09258Mean Accuracy: 0.9935, Test Loss: 1.75182
# Epoch [436/700], Train Loss: 0.10434Mean Accuracy: 0.9935, Test Loss: 1.76203
# Epoch [437/700], Train Loss: 0.09338Mean Accuracy: 0.9935, Test Loss: 1.73985
# Epoch [438/700], Train Loss: 0.09136Mean Accuracy: 0.9935, Test Loss: 1.75711
# Epoch [439/700], Train Loss: 0.09229Mean Accuracy: 0.9934, Test Loss: 1.75060
# Epoch [440/700], Train Loss: 0.09559Mean Accuracy: 0.9935, Test Loss: 1.75819
# Epoch [441/700], Train Loss: 0.09264Mean Accuracy: 0.9935, Test Loss: 1.75222
# Epoch [442/700], Train Loss: 0.09303Mean Accuracy: 0.9935, Test Loss: 1.75033
# Epoch [443/700], Train Loss: 0.08651Mean Accuracy: 0.9935, Test Loss: 1.75377
# Epoch [444/700], Train Loss: 0.08468Mean Accuracy: 0.9935, Test Loss: 1.75009
# Epoch [445/700], Train Loss: 0.08357Mean Accuracy: 0.9935, Test Loss: 1.75933
# Epoch [446/700], Train Loss: 0.08345Mean Accuracy: 0.9935, Test Loss: 1.75532
# Epoch [447/700], Train Loss: 0.08523Mean Accuracy: 0.9935, Test Loss: 1.75924
# Epoch [448/700], Train Loss: 0.08417Mean Accuracy: 0.9934, Test Loss: 1.75843
# Epoch [449/700], Train Loss: 0.09760Mean Accuracy: 0.9934, Test Loss: 1.77976
# Epoch [450/700], Train Loss: 0.26008Mean Accuracy: 0.9927, Test Loss: 2.08005
# Epoch [451/700], Train Loss: 0.59439Mean Accuracy: 0.9931, Test Loss: 1.75092
# Epoch [452/700], Train Loss: 0.36428Mean Accuracy: 0.9934, Test Loss: 1.75261
# Epoch [453/700], Train Loss: 0.30589Mean Accuracy: 0.9933, Test Loss: 1.75121
# Epoch [454/700], Train Loss: 0.26270Mean Accuracy: 0.9934, Test Loss: 1.76696
# Epoch [455/700], Train Loss: 0.19716Mean Accuracy: 0.9934, Test Loss: 1.71769
# Epoch [456/700], Train Loss: 0.16670Mean Accuracy: 0.9934, Test Loss: 1.75492
# Epoch [457/700], Train Loss: 0.14558Mean Accuracy: 0.9935, Test Loss: 1.72456
# Epoch [458/700], Train Loss: 0.10901Mean Accuracy: 0.9935, Test Loss: 1.72876
# Epoch [459/700], Train Loss: 0.08636Mean Accuracy: 0.9935, Test Loss: 1.74764
# Epoch [460/700], Train Loss: 0.08505Mean Accuracy: 0.9935, Test Loss: 1.73217
# Epoch [461/700], Train Loss: 0.07950Mean Accuracy: 0.9935, Test Loss: 1.74444
# Epoch [462/700], Train Loss: 0.07781Mean Accuracy: 0.9935, Test Loss: 1.74303
# Epoch [463/700], Train Loss: 0.07678Mean Accuracy: 0.9935, Test Loss: 1.74394
# Epoch [464/700], Train Loss: 0.07621Mean Accuracy: 0.9935, Test Loss: 1.75091
# Epoch [465/700], Train Loss: 0.07601Mean Accuracy: 0.9935, Test Loss: 1.75056
# Epoch [466/700], Train Loss: 0.07456Mean Accuracy: 0.9935, Test Loss: 1.75296
# Epoch [467/700], Train Loss: 0.07476Mean Accuracy: 0.9935, Test Loss: 1.75063
# Epoch [468/700], Train Loss: 0.07399Mean Accuracy: 0.9935, Test Loss: 1.75511
# Epoch [469/700], Train Loss: 0.07323Mean Accuracy: 0.9935, Test Loss: 1.75682
# Epoch [470/700], Train Loss: 0.07323Mean Accuracy: 0.9935, Test Loss: 1.76053
# Epoch [471/700], Train Loss: 0.07343Mean Accuracy: 0.9935, Test Loss: 1.75747
# Epoch [472/700], Train Loss: 0.07234Mean Accuracy: 0.9935, Test Loss: 1.76030
# Epoch [473/700], Train Loss: 0.07222Mean Accuracy: 0.9935, Test Loss: 1.75543
# Epoch [474/700], Train Loss: 0.07181Mean Accuracy: 0.9935, Test Loss: 1.75525
# Epoch [475/700], Train Loss: 0.07128Mean Accuracy: 0.9935, Test Loss: 1.75769
# Epoch [476/700], Train Loss: 0.07121Mean Accuracy: 0.9935, Test Loss: 1.75876
# Epoch [477/700], Train Loss: 0.07096Mean Accuracy: 0.9935, Test Loss: 1.76139
# Epoch [478/700], Train Loss: 0.07002Mean Accuracy: 0.9935, Test Loss: 1.75623
# Epoch [479/700], Train Loss: 0.06990Mean Accuracy: 0.9935, Test Loss: 1.76550
# Epoch [480/700], Train Loss: 0.06960Mean Accuracy: 0.9935, Test Loss: 1.76075
# Epoch [481/700], Train Loss: 0.06992Mean Accuracy: 0.9935, Test Loss: 1.76627
# Epoch [482/700], Train Loss: 0.06924Mean Accuracy: 0.9935, Test Loss: 1.76168
# Epoch [483/700], Train Loss: 0.06865Mean Accuracy: 0.9935, Test Loss: 1.75934
# Epoch [484/700], Train Loss: 0.06836Mean Accuracy: 0.9935, Test Loss: 1.76456
# Epoch [485/700], Train Loss: 0.06896Mean Accuracy: 0.9935, Test Loss: 1.76687
# Epoch [486/700], Train Loss: 0.06841Mean Accuracy: 0.9935, Test Loss: 1.76482
# Epoch [487/700], Train Loss: 0.06796Mean Accuracy: 0.9935, Test Loss: 1.76952
# Epoch [488/700], Train Loss: 0.06802Mean Accuracy: 0.9935, Test Loss: 1.76814
# Epoch [489/700], Train Loss: 0.06696Mean Accuracy: 0.9935, Test Loss: 1.76899
# Epoch [490/700], Train Loss: 0.06610Mean Accuracy: 0.9935, Test Loss: 1.76859
# Epoch [491/700], Train Loss: 0.06563Mean Accuracy: 0.9935, Test Loss: 1.76707
# Epoch [492/700], Train Loss: 0.06555Mean Accuracy: 0.9935, Test Loss: 1.77124
# Epoch [493/700], Train Loss: 0.06551Mean Accuracy: 0.9935, Test Loss: 1.77292
# Epoch [494/700], Train Loss: 0.06546Mean Accuracy: 0.9935, Test Loss: 1.76956
# Epoch [495/700], Train Loss: 0.06499Mean Accuracy: 0.9935, Test Loss: 1.77419
# Epoch [496/700], Train Loss: 0.06476Mean Accuracy: 0.9935, Test Loss: 1.77149
# Epoch [497/700], Train Loss: 0.06478Mean Accuracy: 0.9935, Test Loss: 1.77548
# Epoch [498/700], Train Loss: 0.06414Mean Accuracy: 0.9935, Test Loss: 1.77690
# Epoch [499/700], Train Loss: 0.06373Mean Accuracy: 0.9935, Test Loss: 1.77546
# Epoch [500/700], Train Loss: 0.06339Mean Accuracy: 0.9935, Test Loss: 1.77050
# Epoch [501/700], Train Loss: 0.06379Mean Accuracy: 0.9935, Test Loss: 1.77906
# Epoch [502/700], Train Loss: 0.06315Mean Accuracy: 0.9934, Test Loss: 1.77254
# Epoch [503/700], Train Loss: 0.06276Mean Accuracy: 0.9935, Test Loss: 1.77581
# Epoch [504/700], Train Loss: 0.06203Mean Accuracy: 0.9935, Test Loss: 1.78127
# Epoch [505/700], Train Loss: 0.06187Mean Accuracy: 0.9934, Test Loss: 1.77847
# Epoch [506/700], Train Loss: 0.06454Mean Accuracy: 0.9934, Test Loss: 1.78188
# Epoch [507/700], Train Loss: 0.06293Mean Accuracy: 0.9935, Test Loss: 1.78423
# Epoch [508/700], Train Loss: 0.06162Mean Accuracy: 0.9934, Test Loss: 1.78107
# Epoch [509/700], Train Loss: 0.06123Mean Accuracy: 0.9935, Test Loss: 1.77818
# Epoch [510/700], Train Loss: 0.06127Mean Accuracy: 0.9935, Test Loss: 1.78174
# Epoch [511/700], Train Loss: 0.06048Mean Accuracy: 0.9935, Test Loss: 1.77693
# Epoch [512/700], Train Loss: 0.05990Mean Accuracy: 0.9934, Test Loss: 1.78351
# Epoch [513/700], Train Loss: 0.06019Mean Accuracy: 0.9935, Test Loss: 1.78102
# Epoch [514/700], Train Loss: 0.06020Mean Accuracy: 0.9934, Test Loss: 1.78241
# Epoch [515/700], Train Loss: 0.06112Mean Accuracy: 0.9934, Test Loss: 1.78960
# Epoch [516/700], Train Loss: 0.06092Mean Accuracy: 0.9934, Test Loss: 1.78892
# Epoch [517/700], Train Loss: 0.05995Mean Accuracy: 0.9934, Test Loss: 1.78661
# Epoch [518/700], Train Loss: 0.05957Mean Accuracy: 0.9934, Test Loss: 1.79052
# Epoch [519/700], Train Loss: 0.06025Mean Accuracy: 0.9934, Test Loss: 1.78248
# Epoch [520/700], Train Loss: 0.05865Mean Accuracy: 0.9935, Test Loss: 1.78818
# Epoch [521/700], Train Loss: 0.05857Mean Accuracy: 0.9934, Test Loss: 1.78697
# Epoch [522/700], Train Loss: 0.05852Mean Accuracy: 0.9934, Test Loss: 1.78275
# Epoch [523/700], Train Loss: 0.05825Mean Accuracy: 0.9935, Test Loss: 1.78954
# Epoch [524/700], Train Loss: 0.05779Mean Accuracy: 0.9934, Test Loss: 1.78389
# Epoch [525/700], Train Loss: 0.05718Mean Accuracy: 0.9934, Test Loss: 1.78844
# Epoch [526/700], Train Loss: 0.05812Mean Accuracy: 0.9934, Test Loss: 1.79067
# Epoch [527/700], Train Loss: 0.05927Mean Accuracy: 0.9934, Test Loss: 1.79504
# Epoch [528/700], Train Loss: 0.05794Mean Accuracy: 0.9934, Test Loss: 1.79230
# Epoch [529/700], Train Loss: 0.05777Mean Accuracy: 0.9934, Test Loss: 1.79354
# Epoch [530/700], Train Loss: 0.05612Mean Accuracy: 0.9934, Test Loss: 1.78843
# Epoch [531/700], Train Loss: 0.05559Mean Accuracy: 0.9934, Test Loss: 1.79231
# Epoch [532/700], Train Loss: 0.05553Mean Accuracy: 0.9935, Test Loss: 1.78575
# Epoch [533/700], Train Loss: 0.05557Mean Accuracy: 0.9934, Test Loss: 1.79206
# Epoch [534/700], Train Loss: 0.05551Mean Accuracy: 0.9934, Test Loss: 1.79524
# Epoch [535/700], Train Loss: 0.05470Mean Accuracy: 0.9934, Test Loss: 1.79493
# Epoch [536/700], Train Loss: 0.05468Mean Accuracy: 0.9934, Test Loss: 1.79438
# Epoch [537/700], Train Loss: 0.05425Mean Accuracy: 0.9934, Test Loss: 1.78968
# Epoch [538/700], Train Loss: 0.05408Mean Accuracy: 0.9934, Test Loss: 1.79754
# Epoch [539/700], Train Loss: 0.05399Mean Accuracy: 0.9934, Test Loss: 1.79779
# Epoch [540/700], Train Loss: 0.05383Mean Accuracy: 0.9934, Test Loss: 1.79661
# Epoch [541/700], Train Loss: 0.05328Mean Accuracy: 0.9934, Test Loss: 1.79460
# Epoch [542/700], Train Loss: 0.05301Mean Accuracy: 0.9934, Test Loss: 1.79404
# Epoch [543/700], Train Loss: 0.05293Mean Accuracy: 0.9934, Test Loss: 1.79629
# Epoch [544/700], Train Loss: 0.05257Mean Accuracy: 0.9934, Test Loss: 1.79798
# Epoch [545/700], Train Loss: 0.05238Mean Accuracy: 0.9934, Test Loss: 1.79836
# Epoch [546/700], Train Loss: 0.05268Mean Accuracy: 0.9934, Test Loss: 1.79901
# Epoch [547/700], Train Loss: 0.05253Mean Accuracy: 0.9934, Test Loss: 1.79838
# Epoch [548/700], Train Loss: 0.05202Mean Accuracy: 0.9934, Test Loss: 1.79900
# Epoch [549/700], Train Loss: 0.05184Mean Accuracy: 0.9934, Test Loss: 1.79914
# Epoch [550/700], Train Loss: 0.05235Mean Accuracy: 0.9934, Test Loss: 1.79871
# Epoch [551/700], Train Loss: 0.05195Mean Accuracy: 0.9934, Test Loss: 1.80035
# Epoch [552/700], Train Loss: 0.05144Mean Accuracy: 0.9934, Test Loss: 1.80573
# Epoch [553/700], Train Loss: 0.05204Mean Accuracy: 0.9934, Test Loss: 1.80153
# Epoch [554/700], Train Loss: 0.05168Mean Accuracy: 0.9934, Test Loss: 1.80377
# Epoch [555/700], Train Loss: 0.05098Mean Accuracy: 0.9934, Test Loss: 1.80140
# Epoch [556/700], Train Loss: 0.05089Mean Accuracy: 0.9934, Test Loss: 1.80048
# Epoch [557/700], Train Loss: 0.05035Mean Accuracy: 0.9934, Test Loss: 1.79839
# Epoch [558/700], Train Loss: 0.05041Mean Accuracy: 0.9934, Test Loss: 1.80807
# Epoch [559/700], Train Loss: 0.05054Mean Accuracy: 0.9934, Test Loss: 1.79659
# Epoch [560/700], Train Loss: 0.04988Mean Accuracy: 0.9934, Test Loss: 1.80176
# Epoch [561/700], Train Loss: 0.05016Mean Accuracy: 0.9934, Test Loss: 1.80214
# Epoch [562/700], Train Loss: 0.05027Mean Accuracy: 0.9934, Test Loss: 1.79784
# Epoch [563/700], Train Loss: 0.04996Mean Accuracy: 0.9934, Test Loss: 1.80236
# Epoch [564/700], Train Loss: 0.04996Mean Accuracy: 0.9934, Test Loss: 1.80470
# Epoch [565/700], Train Loss: 0.05039Mean Accuracy: 0.9934, Test Loss: 1.80540
# Epoch [566/700], Train Loss: 0.04883Mean Accuracy: 0.9934, Test Loss: 1.80142
# Epoch [567/700], Train Loss: 0.04888Mean Accuracy: 0.9934, Test Loss: 1.80535
# Epoch [568/700], Train Loss: 0.04878Mean Accuracy: 0.9934, Test Loss: 1.80938
# Epoch [569/700], Train Loss: 0.04851Mean Accuracy: 0.9934, Test Loss: 1.80206
# Epoch [570/700], Train Loss: 0.04815Mean Accuracy: 0.9934, Test Loss: 1.80547
# Epoch [571/700], Train Loss: 0.04801Mean Accuracy: 0.9934, Test Loss: 1.80427
# Epoch [572/700], Train Loss: 0.04792Mean Accuracy: 0.9934, Test Loss: 1.80571
# Epoch [573/700], Train Loss: 0.04771Mean Accuracy: 0.9934, Test Loss: 1.80796
# Epoch [574/700], Train Loss: 0.04784Mean Accuracy: 0.9934, Test Loss: 1.80715
# Epoch [575/700], Train Loss: 0.04765Mean Accuracy: 0.9934, Test Loss: 1.80785
# Epoch [576/700], Train Loss: 0.04778Mean Accuracy: 0.9934, Test Loss: 1.80616
# Epoch [577/700], Train Loss: 0.04747Mean Accuracy: 0.9934, Test Loss: 1.80428
# Epoch [578/700], Train Loss: 0.04719Mean Accuracy: 0.9934, Test Loss: 1.80883
# Epoch [579/700], Train Loss: 0.04716Mean Accuracy: 0.9934, Test Loss: 1.81140
# Epoch [580/700], Train Loss: 0.04692Mean Accuracy: 0.9934, Test Loss: 1.81085
# Epoch [581/700], Train Loss: 0.04688Mean Accuracy: 0.9934, Test Loss: 1.80849
# Epoch [582/700], Train Loss: 0.04667Mean Accuracy: 0.9934, Test Loss: 1.81111
# Epoch [583/700], Train Loss: 0.04640Mean Accuracy: 0.9934, Test Loss: 1.80834
# Epoch [584/700], Train Loss: 0.04658Mean Accuracy: 0.9934, Test Loss: 1.80791
# Epoch [585/700], Train Loss: 0.04636Mean Accuracy: 0.9934, Test Loss: 1.81115
# Epoch [586/700], Train Loss: 0.04624Mean Accuracy: 0.9934, Test Loss: 1.81156
# Epoch [587/700], Train Loss: 0.04619Mean Accuracy: 0.9934, Test Loss: 1.81424
# Epoch [588/700], Train Loss: 0.04610Mean Accuracy: 0.9934, Test Loss: 1.81237
# Epoch [589/700], Train Loss: 0.04602Mean Accuracy: 0.9934, Test Loss: 1.81240
# Epoch [590/700], Train Loss: 0.04579Mean Accuracy: 0.9934, Test Loss: 1.81142
# Epoch [591/700], Train Loss: 0.04561Mean Accuracy: 0.9934, Test Loss: 1.80817
# Epoch [592/700], Train Loss: 0.04552Mean Accuracy: 0.9934, Test Loss: 1.80688
# Epoch [593/700], Train Loss: 0.04552Mean Accuracy: 0.9934, Test Loss: 1.81091
# Epoch [594/700], Train Loss: 0.04538Mean Accuracy: 0.9934, Test Loss: 1.81302
# Epoch [595/700], Train Loss: 0.04542Mean Accuracy: 0.9934, Test Loss: 1.81552
# Epoch [596/700], Train Loss: 0.04543Mean Accuracy: 0.9934, Test Loss: 1.81549
# Epoch [597/700], Train Loss: 0.04531Mean Accuracy: 0.9934, Test Loss: 1.81223
# Epoch [598/700], Train Loss: 0.04495Mean Accuracy: 0.9934, Test Loss: 1.81055
# Epoch [599/700], Train Loss: 0.04482Mean Accuracy: 0.9934, Test Loss: 1.81331
# Epoch [600/700], Train Loss: 0.04458Mean Accuracy: 0.9934, Test Loss: 1.81270
# Epoch [601/700], Train Loss: 0.04464Mean Accuracy: 0.9934, Test Loss: 1.81572
# Epoch [602/700], Train Loss: 0.04449Mean Accuracy: 0.9934, Test Loss: 1.81516
# Epoch [603/700], Train Loss: 0.04438Mean Accuracy: 0.9934, Test Loss: 1.81190
# Epoch [604/700], Train Loss: 0.04420Mean Accuracy: 0.9934, Test Loss: 1.81561
# Epoch [605/700], Train Loss: 0.04413Mean Accuracy: 0.9934, Test Loss: 1.81460
# Epoch [606/700], Train Loss: 0.04400Mean Accuracy: 0.9934, Test Loss: 1.81550
# Epoch [607/700], Train Loss: 0.04404Mean Accuracy: 0.9934, Test Loss: 1.81371
# Epoch [608/700], Train Loss: 0.04384Mean Accuracy: 0.9934, Test Loss: 1.81357
# Epoch [609/700], Train Loss: 0.04388Mean Accuracy: 0.9934, Test Loss: 1.81496
# Epoch [610/700], Train Loss: 0.04370Mean Accuracy: 0.9934, Test Loss: 1.81607
# Epoch [611/700], Train Loss: 0.04356Mean Accuracy: 0.9934, Test Loss: 1.81566
# Epoch [612/700], Train Loss: 0.04361Mean Accuracy: 0.9934, Test Loss: 1.81757
# Epoch [613/700], Train Loss: 0.04357Mean Accuracy: 0.9934, Test Loss: 1.81530
# Epoch [614/700], Train Loss: 0.04348Mean Accuracy: 0.9934, Test Loss: 1.81558
# Epoch [615/700], Train Loss: 0.04339Mean Accuracy: 0.9934, Test Loss: 1.81829
# Epoch [616/700], Train Loss: 0.04353Mean Accuracy: 0.9934, Test Loss: 1.81722
# Epoch [617/700], Train Loss: 0.04334Mean Accuracy: 0.9934, Test Loss: 1.81753
# Epoch [618/700], Train Loss: 0.04318Mean Accuracy: 0.9934, Test Loss: 1.81749
# Epoch [619/700], Train Loss: 0.04319Mean Accuracy: 0.9934, Test Loss: 1.82013
# Epoch [620/700], Train Loss: 0.04310Mean Accuracy: 0.9934, Test Loss: 1.81674
# Epoch [621/700], Train Loss: 0.04294Mean Accuracy: 0.9934, Test Loss: 1.81777
# Epoch [622/700], Train Loss: 0.04284Mean Accuracy: 0.9934, Test Loss: 1.81706
# Epoch [623/700], Train Loss: 0.04291Mean Accuracy: 0.9934, Test Loss: 1.81782
# Epoch [624/700], Train Loss: 0.04303Mean Accuracy: 0.9934, Test Loss: 1.81935
# Epoch [625/700], Train Loss: 0.04273Mean Accuracy: 0.9934, Test Loss: 1.81849
# Epoch [626/700], Train Loss: 0.04257Mean Accuracy: 0.9934, Test Loss: 1.81857
# Epoch [627/700], Train Loss: 0.04254Mean Accuracy: 0.9934, Test Loss: 1.81878
# Epoch [628/700], Train Loss: 0.04252Mean Accuracy: 0.9934, Test Loss: 1.81786
# Epoch [629/700], Train Loss: 0.04268Mean Accuracy: 0.9934, Test Loss: 1.81846
# Epoch [630/700], Train Loss: 0.04242Mean Accuracy: 0.9934, Test Loss: 1.81870
# Epoch [631/700], Train Loss: 0.04232Mean Accuracy: 0.9934, Test Loss: 1.81892
# Epoch [632/700], Train Loss: 0.04226Mean Accuracy: 0.9934, Test Loss: 1.81898
# Epoch [633/700], Train Loss: 0.04218Mean Accuracy: 0.9934, Test Loss: 1.81826
# Epoch [634/700], Train Loss: 0.04212Mean Accuracy: 0.9934, Test Loss: 1.82024
# Epoch [635/700], Train Loss: 0.04205Mean Accuracy: 0.9934, Test Loss: 1.81942
# Epoch [636/700], Train Loss: 0.04199Mean Accuracy: 0.9934, Test Loss: 1.81936
# Epoch [637/700], Train Loss: 0.04197Mean Accuracy: 0.9934, Test Loss: 1.82063
# Epoch [638/700], Train Loss: 0.04189Mean Accuracy: 0.9934, Test Loss: 1.81969
# Epoch [639/700], Train Loss: 0.04185Mean Accuracy: 0.9934, Test Loss: 1.82077
# Epoch [640/700], Train Loss: 0.04182Mean Accuracy: 0.9934, Test Loss: 1.81936
# Epoch [641/700], Train Loss: 0.04179Mean Accuracy: 0.9934, Test Loss: 1.82040
# Epoch [642/700], Train Loss: 0.04177Mean Accuracy: 0.9934, Test Loss: 1.82012
# Epoch [643/700], Train Loss: 0.04174Mean Accuracy: 0.9934, Test Loss: 1.82076
# Epoch [644/700], Train Loss: 0.04166Mean Accuracy: 0.9934, Test Loss: 1.81963
# Epoch [645/700], Train Loss: 0.04167Mean Accuracy: 0.9934, Test Loss: 1.81946
# Epoch [646/700], Train Loss: 0.04159Mean Accuracy: 0.9934, Test Loss: 1.81981
# Epoch [647/700], Train Loss: 0.04152Mean Accuracy: 0.9934, Test Loss: 1.82102
# Epoch [648/700], Train Loss: 0.04148Mean Accuracy: 0.9934, Test Loss: 1.82021
# Epoch [649/700], Train Loss: 0.04149Mean Accuracy: 0.9934, Test Loss: 1.82050
# Epoch [650/700], Train Loss: 0.04148Mean Accuracy: 0.9934, Test Loss: 1.82082
# Epoch [651/700], Train Loss: 0.04152Mean Accuracy: 0.9934, Test Loss: 1.82046
# Epoch [652/700], Train Loss: 0.04137Mean Accuracy: 0.9934, Test Loss: 1.82091
# Epoch [653/700], Train Loss: 0.04130Mean Accuracy: 0.9934, Test Loss: 1.82131
# Epoch [654/700], Train Loss: 0.04128Mean Accuracy: 0.9934, Test Loss: 1.82121
# Epoch [655/700], Train Loss: 0.04122Mean Accuracy: 0.9934, Test Loss: 1.82088
# Epoch [656/700], Train Loss: 0.04121Mean Accuracy: 0.9934, Test Loss: 1.82084
# Epoch [657/700], Train Loss: 0.04119Mean Accuracy: 0.9934, Test Loss: 1.82130
# Epoch [658/700], Train Loss: 0.04120Mean Accuracy: 0.9934, Test Loss: 1.82076
# Epoch [659/700], Train Loss: 0.04115Mean Accuracy: 0.9934, Test Loss: 1.82127
# Epoch [660/700], Train Loss: 0.04117Mean Accuracy: 0.9934, Test Loss: 1.82105
# Epoch [661/700], Train Loss: 0.04115Mean Accuracy: 0.9934, Test Loss: 1.82164
# Epoch [662/700], Train Loss: 0.04110Mean Accuracy: 0.9934, Test Loss: 1.82094
# Epoch [663/700], Train Loss: 0.04107Mean Accuracy: 0.9934, Test Loss: 1.82196
# Epoch [664/700], Train Loss: 0.04108Mean Accuracy: 0.9934, Test Loss: 1.82104
# Epoch [665/700], Train Loss: 0.04104Mean Accuracy: 0.9934, Test Loss: 1.82201
# Epoch [666/700], Train Loss: 0.04099Mean Accuracy: 0.9934, Test Loss: 1.82152
# Epoch [667/700], Train Loss: 0.04096Mean Accuracy: 0.9934, Test Loss: 1.82183
# Epoch [668/700], Train Loss: 0.04094Mean Accuracy: 0.9934, Test Loss: 1.82128
# Epoch [669/700], Train Loss: 0.04094Mean Accuracy: 0.9934, Test Loss: 1.82169
# Epoch [670/700], Train Loss: 0.04092Mean Accuracy: 0.9934, Test Loss: 1.82164
# Epoch [671/700], Train Loss: 0.04091Mean Accuracy: 0.9934, Test Loss: 1.82173
# Epoch [672/700], Train Loss: 0.04089Mean Accuracy: 0.9934, Test Loss: 1.82185
# Epoch [673/700], Train Loss: 0.04089Mean Accuracy: 0.9934, Test Loss: 1.82160
# Epoch [674/700], Train Loss: 0.04088Mean Accuracy: 0.9934, Test Loss: 1.82162
# Epoch [675/700], Train Loss: 0.04087Mean Accuracy: 0.9934, Test Loss: 1.82194
# Epoch [676/700], Train Loss: 0.04085Mean Accuracy: 0.9934, Test Loss: 1.82219
# Epoch [677/700], Train Loss: 0.04084Mean Accuracy: 0.9934, Test Loss: 1.82158
# Epoch [678/700], Train Loss: 0.04082Mean Accuracy: 0.9934, Test Loss: 1.82233
# Epoch [679/700], Train Loss: 0.04081Mean Accuracy: 0.9934, Test Loss: 1.82195
# Epoch [680/700], Train Loss: 0.04080Mean Accuracy: 0.9934, Test Loss: 1.82170
# Epoch [681/700], Train Loss: 0.04079Mean Accuracy: 0.9934, Test Loss: 1.82215
# Epoch [682/700], Train Loss: 0.04078Mean Accuracy: 0.9934, Test Loss: 1.82198
# Epoch [683/700], Train Loss: 0.04077Mean Accuracy: 0.9934, Test Loss: 1.82195
# Epoch [684/700], Train Loss: 0.04077Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [685/700], Train Loss: 0.04075Mean Accuracy: 0.9934, Test Loss: 1.82209
# Epoch [686/700], Train Loss: 0.04075Mean Accuracy: 0.9934, Test Loss: 1.82192
# Epoch [687/700], Train Loss: 0.04075Mean Accuracy: 0.9934, Test Loss: 1.82197
# Epoch [688/700], Train Loss: 0.04074Mean Accuracy: 0.9934, Test Loss: 1.82190
# Epoch [689/700], Train Loss: 0.04074Mean Accuracy: 0.9934, Test Loss: 1.82196
# Epoch [690/700], Train Loss: 0.04073Mean Accuracy: 0.9934, Test Loss: 1.82192
# Epoch [691/700], Train Loss: 0.04073Mean Accuracy: 0.9934, Test Loss: 1.82190
# Epoch [692/700], Train Loss: 0.04072Mean Accuracy: 0.9934, Test Loss: 1.82193
# Epoch [693/700], Train Loss: 0.04073Mean Accuracy: 0.9934, Test Loss: 1.82198
# Epoch [694/700], Train Loss: 0.04072Mean Accuracy: 0.9934, Test Loss: 1.82198
# Epoch [695/700], Train Loss: 0.04072Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [696/700], Train Loss: 0.04072Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [697/700], Train Loss: 0.04071Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [698/700], Train Loss: 0.04071Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [699/700], Train Loss: 0.04071Mean Accuracy: 0.9934, Test Loss: 1.82199
# Epoch [700/700], Train Loss: 0.04071Mean Accuracy: 0.9934, Test Loss: 1.82199
# Loaded best model weights with test loss: 1.54972, epoch:  59
# Training Complete

# %%
from sklearn.metrics import confusion_matrix
import torch

model.eval()
correct = 0
total = 0
test_loss = 0.0
model = trained_model

all_labels = []
all_preds = []
criterion = nn.MSELoss()
with torch.no_grad():
    for images, targets, labels, init_data in test_loader:
        images = normalize_targets(images,input_norm_values).to(device)
       # images = images.to(device)
        labels = labels.to(device)           # shape: [B, 2738]
        targets = normalize_targets(targets, norm_values).to(device)
        attention_mask = create_attention_mask(images).to(device)

        outputs, outputs_class = model(images, None)
        loss = criterion(denormalize_targets(outputs,norm_values), denormalize_targets(targets,norm_values))
        test_loss += loss.item() * images.size(0)

        probs = torch.sigmoid(outputs_class)      # [B, 2738]
        preds = (probs > 0.5).float()

        correct += (preds == labels).sum().item()
        total += labels.numel()

        all_labels.append(labels.cpu())
        all_preds.append(preds.cpu())

# Global accuracy
mean_accuracy = correct / total
mean_test_loss = test_loss / len(test_loader.dataset)
print(f"Mean Accuracy: {mean_accuracy:.4f}, Test Loss: {mean_test_loss:.5f}")

# Confusion matrix (aggregated across all 2738×B predictions)
all_labels_flat = torch.cat(all_labels).view(-1).numpy()
all_preds_flat = torch.cat(all_preds).view(-1).numpy()

cm = confusion_matrix(all_labels_flat, all_preds_flat, labels=[1, 0])
if cm.shape == (2, 2):
    TP, FN = cm[0]
    FP, TN = cm[1]
    print("\nConfusion Matrix:")
    print(f"  True Positives : {TP}")
    print(f"  False Positives: {FP}")
    print(f"  False Negatives: {FN}")
    print(f"  True Negatives : {TN}")
else:
    print("\nConfusion Matrix could not be computed due to class imbalance.")
# Out:
# Mean Accuracy: 0.9909, Test Loss: 1.54972
#
# Confusion Matrix:
#   True Positives : 47169
#   False Positives: 10129
#   False Negatives: 14815
#   True Negatives : 2663149

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def plot_points_sequence_3d_separate(init_coord_data, gt_data, predicted_displacements, connect_points=True):
    """
    Plots two separate 3D figures: one for ground truth points and one for predicted points.

    Args:
        init_coord_data (numpy.ndarray): Initial positions of shape (N, 3).
        gt_data (numpy.ndarray): Ground truth displacements of shape (N, 3).
        predicted_displacements (numpy.ndarray): Predicted displacements of shape (N, 3).
        connect_points (bool): Whether to draw lines connecting successive points.
    """
    # Compute final positions
    gt_points = init_coord_data + gt_data
    predicted_points = init_coord_data + predicted_displacements

    # ---------- Ground Truth Figure ----------
    fig_gt = plt.figure(figsize=(10, 8))
    ax_gt = fig_gt.add_subplot(111, projection='3d')
    ax_gt.scatter(gt_points[:, 0], gt_points[:, 1], gt_points[:, 2],
                  color='green', label='Ground Truth Points', marker='x', s=10)

    if connect_points:
        for i in range(len(gt_points) - 1):
            ax_gt.plot([gt_points[i, 0], gt_points[i + 1, 0]],
                       [gt_points[i, 1], gt_points[i + 1, 1]],
                       [gt_points[i, 2], gt_points[i + 1, 2]], 'g-', alpha=0.5)

    ax_gt.set_title('Ground Truth 3D Points')
    ax_gt.set_xlabel('X')
    ax_gt.set_ylabel('Y')
    ax_gt.set_zlabel('Z')
    ax_gt.legend()
    plt.grid(True)

    # ---------- Predicted Points Figure ----------
    fig_pred = plt.figure(figsize=(10, 8))
    ax_pred = fig_pred.add_subplot(111, projection='3d')
    ax_pred.scatter(predicted_points[:, 0], predicted_points[:, 1], predicted_points[:, 2],
                    color='red', label='Predicted Points', marker='o', s=10)

    if connect_points:
        for i in range(len(predicted_points) - 1):
            ax_pred.plot([predicted_points[i, 0], predicted_points[i + 1, 0]],
                         [predicted_points[i, 1], predicted_points[i + 1, 1]],
                         [predicted_points[i, 2], predicted_points[i + 1, 2]], 'r-', alpha=0.5)

    ax_pred.set_title('Predicted 3D Points')
    ax_pred.set_xlabel('X')
    ax_pred.set_ylabel('Y')
    ax_pred.set_zlabel('Z')
    ax_pred.legend()
    plt.grid(True)

    # Show both figures
    plt.show()



# Example usage for a given sample index
# Assuming `init_coord_data`, `gt_data`, and `predicted_displacements` are NumPy arrays of shape (N, 2)
# For example:
images, targets, labels, init_data = test_loader.dataset[78]
images = normalize_targets(images,input_norm_values).to(device)
#images = images.to(device)
images = images[None, :, :]
attention_mask = create_attention_mask(images).to(device)
init_data = init_data.numpy().reshape(-1,3)
targets = targets.numpy().reshape(-1,3)

predicted_displacements,_ = trained_model(images,None)
predicted_displacements = denormalize_targets(predicted_displacements,norm_values)
predicted_displacements = predicted_displacements.cpu().detach().numpy()
predicted_displacements = predicted_displacements.reshape(-1,3)
#import pdb; pdb.set_trace()
# Call the function to plot the points for a sample
plot_points_sequence_3d_separate(init_data, targets, predicted_displacements,connect_points=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# tensor([-0.0023,  0.0665, -0.2417, -0.0099, -0.0222, -0.2324, -0.0082,  0.0673,
#         -0.2432, -0.0032])

# %%
def plot_image_tensor(image_tensor):
    """
    Takes a PyTorch tensor representing image data and plots the image.

    Args:
        image_tensor (torch.Tensor): A tensor representing image data with shape 
                                     (batch_size, channels, height, width).
    """
    # Check if the tensor is a single image or a batch
    if image_tensor.ndimension() == 4:
        # If batch size is greater than 1, let's plot the first image
        image_tensor = image_tensor[0]  # Take the first image in the batch
    
    # Convert the tensor to a NumPy array and move channels to last dimension (for plotting)
    image_array = image_tensor.numpy().transpose((1, 2, 0))  # Convert from (C, H, W) to (H, W, C)
    #image_array[:, :, 1] = 1
    # If the image is grayscale (single channel), it will have only one channel
    if image_array.shape[2] == 1:
        image_array = image_array[:, :, 0]  # Convert to 2D for grayscale images
    
    # Plot the image
    plt.imshow(image_array, cmap='gray' if image_array.ndim == 2 else None)
    plt.axis('off')  # Hide axes
    plt.show()

plot_image_tensor(images[:,:,:,:].cpu())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 26
#      23     plt.axis('off')  # Hide axes
#      24     plt.show()
# ---> 26 plot_image_tensor(images[:,:,:,:].cpu())
#
# IndexError: too many indices for tensor of dimension 3

# %%
images.shape
